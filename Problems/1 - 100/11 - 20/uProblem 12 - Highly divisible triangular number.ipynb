# %% [markdown]
# ### Problem 12 ###
#
# The sequence of triangle numbers is generated by adding the natural numbers. So the 7th triangle number would be 1 + 2 + 3 + 4 + 5 + 6 + 7 = 28. The first ten terms would be:
#
# 1, 3, 6, 10, 15, 21, 28, 36, 45, 55, ...
#
# Let us list the factors of the first seven triangle numbers:
#
#  1: 1
#  3: 1,3
#  6: 1,2,3,6
# 10: 1,2,5,10
# 15: 1,3,5,15
# 21: 1,3,7,21
#
# 28: 1,2,4,7,14,28
# We can see that 28 is the first triangle number to have over five divisors.
#
# What is the value of the first triangle number to have over five hundred divisors?

# %%
import numpy as np
from time import clock
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def triangles(n):
    'returns a list with the firsts n triangle numbers'
    t = [1]
    for i in range(n):
        t.append(t[i] +  len(t) + 1 )
    return t[-1]

# %%
def divcount(x):
    'returns the number of divisors of x, recursively'
    divisors = [1,x]
    i = 2
    y = x
    ans = 2
    while y > 1:
        if x%i == 0:
            if i not in divisors:
                divisors.append(i)
                ans += 1 
            y = y/i
        i += 1
    if len(divisors) > 2:
        for divid in divisors[2:]:
            ans += divcount(divid) - 2
    return ans

# %%
def ans12(x):
    i = 0
    t = [1]
    u = t[-1]
    k = divcount(u)
    while k < x:
        j = 0
        t.append(t[i] +  len(t) + 1 )
        u = t[-1]
        i += 1
        k = divcount(u)
        
        
        
    return u,str(k) + ' divisors',str(i) + ' iteractions'

# %%
ans12(50)
# Out:
# (225728128, '50 divisors', '21246 iteractions')

# %%
ii = np.arange(50)
ts = []

# %%
for i in ii:
    t0 = clock()
    ans12(i)
    t1 = clock()
    tf = t1-t0
    ts.append(tf)

# %%
plot(ii,ts[50:]);

# %%
def divcounter(x):
    'counts the number of divisors of x'
    a = int(np.ceil(x**(1/2)))
    k = [1,x]
    for i in range(a,1,-1):
        if x%i == 0:
            k.append(i)
            k.append(int(x/i))
        
    return len(k)

# %%
divcounter(28)
# Out:
# 6

# %%
def countcount(x):
    a = int(np.floor(x**(1/2)))
    divid = 2
    for p in get_primes(a):
        if x%p == 0:
            x = x/p
            divid += 1
    return divid

# %%
countcount(12)
# Out:
# 4

# %%
def triangln(n):
    'returns the nth triangle number'
    return n*(n+1)*(0.5)

# %%
import numpy as np

# %%
xs =np.arange(11)

# %%
for x in xs[1:]:
    print(x,triangln(x),divcount(x))
# Out:
# 1 1.0 [1, 1, 1, 1]
# 2 3.0 [1, 1, 3, 3]
# 3 6.0 [1, 3, 2, 6]
# 4 10.0 [1, 2, 5, 10]
# 5 15.0 [1, 5, 3, 15]
# 6 21.0 [1, 3, 7, 21]
# 7 28.0 [1, 7, 4, 28]
# 8 36.0 [1, 4, 9, 36, 2]
# 9 45.0 [1, 9, 5, 45]
# 10 55.0 [1, 5, 11, 55]

# %%
triangln(7)
# Out:
# 28.0

# %%
def divcount(x):
    'returns the number of divisor of xth triangle number'
    if x%2 == 0:
        a = int(x*(0.5))
        b = int((x+1))
        numb = int(a*b) 
        div = [1,a,b,numb]
    else:
        a = int(x)
        b = int((x+1)*(0.5))
        numb = int(a*b )
        div = [1,a,b,numb]
        
        
        
    ans = 2    
    i = 2
    while i < (x+1)/4 :
        if a%i == 0:
            if i not in div:
                div.append(i)
            a = a/i
        if b%i == 0:
            if i not in div:
                div.append(i)
            b = b/i
        i += 1 
    return (div)

# %%
divcount(3)
# Out:
# [1, 3, 2, 6]

# %%
def divisors(k):
    'return the number of divisors o any given number k'
    i  = 2 # k and 1
    if k%2== 0:
    while i < k/2:

# %%
def divdiv(divs):
    'return the numbers of divisors'
    div1 = divs[0]
    div2 = divs[1]
    m = divisors(div1)
    n = divisors(div2)
    return m*n

# %%
def divcount(divsors):
    'returns the first triangular number with more or equal divisors'
    l = 0
    i = 1
    while  l < divsors:
        if i%2 == 0:
            divs =  [i*0.5,i+1]
        else:
            divs= [i,(i+1)*0.5]
        l = divdiv(divs)
