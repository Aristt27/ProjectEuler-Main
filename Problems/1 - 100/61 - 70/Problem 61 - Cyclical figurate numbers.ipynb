# %% [markdown]
# ### Problem 61 ###
#
# Triangle, square, pentagonal, hexagonal, heptagonal, and octagonal numbers are all figurate (polygonal) numbers and are generated by the following formulae:
#
#     Triangle	 	P3,n=n(n+1)/2	 	1, 3, 6, 10, 15, ...
#     Square	 	  P4,n=n2	 	      1, 4, 9, 16, 25, ...
#     Pentagonal	   P5,n=n(3n−1)/2	    1, 5, 12, 22, 35, ...
#     Hexagonal	    P6,n=n(2n−1)	 	 1, 6, 15, 28, 45, ...
#     Heptagonal	   P7,n=n(5n−3)/2	    1, 7, 18, 34, 55, ...
#     Octagonal	    P8,n=n(3n−2)	      1, 8, 21, 40, 65, ...
# The ordered set of three 4-digit numbers: 8128, 2882, 8281, has three interesting properties.
#
# The set is cyclic, in that the last two digits of each number is the first two digits of the next number (including the last number with the first).
# Each polygonal type: triangle (P3,127=8128), square (P4,91=8281), and pentagonal (P5,44=2882), is represented by a different number in the set.
# This is the only set of 4-digit numbers with this property.
# Find the sum of the only ordered set of six cyclic 4-digit numbers for which each polygonal type: triangle, square, pentagonal, hexagonal, heptagonal, and octagonal, is represented by a different number in the set.

# %%
trilist = [int(n*(n+1)/2) for n in range(45,141)]
sqlist = [int(n**2) for n in range(34,100)]
pentlist = [int(n*(3*n-1)/2) for n in range(26,82)]
hexalist = [int(n*(2*n-1)) for n in range(23,71)]
heptlist = [int(n*(5*n-3)/2) for n in range(21,64)]
octolist = [int(n*(3*n-2)) for n in range(19,59)]

# %%
ts = []
st = []

# %%
for t in trilist:
    for s in sqlist:
        if [str(t)[-2],str(t)[-1]] == [str(s)[0],str(s)[1]]:
            ts.append([t,s])
        if [str(s)[-2],str(s)[-1]] == [str(t)[0],str(t)[1]]:
            st.append([s,t])

# %%
len(st),len(ts)
# Out:
# (48, 68)

# %%
tp = []
pt = []

# %%
for t in trilist:
    for p in pentlist:
        if [str(t)[-2],str(t)[-1]] == [str(p)[0],str(p)[1]]:
            tp.append([t,p])
        if [str(p)[-2],str(p)[-1]] == [str(t)[0],str(t)[1]]:
            pt.append([p,t])

# %%
len(pt),len(tp)
# Out:
# (58, 62)

# %%
thexa = []
hexat = []

# %%
for t in trilist:
    for hexa in hexalist:
        if [str(t)[-2],str(t)[-1]] == [str(hexa)[0],str(hexa)[1]]:
            thexa.append([t,hexa])
        if [str(hexa)[-2],str(hexa)[-1]] == [str(t)[0],str(t)[1]]:
            hexat.append([hexa,t])

# %%
len(hexat),len(thexa)
# Out:
# (47, 53)

# %%
thept = []
heptt = []

# %%
for t in trilist:
    for hept in heptlist:
        if [str(t)[-2],str(t)[-1]] == [str(hept)[0],str(hept)[1]]:
            thept.append([t,hept])
        if [str(hept)[-2],str(hept)[-1]] == [str(t)[0],str(t)[1]]:
            heptt.append([hept,t])

# %%
len(thept),len(heptt)
# Out:
# (38, 45)

# %%
tocto = []
octot = []

# %%
for t in trilist:
    for octo in hexalist:
        if [str(t)[-2],str(t)[-1]] == [str(octo)[0],str(octo)[1]]:
            tocto.append([t,octo])
        if [str(octo)[-2],str(octo)[-1]] == [str(t)[0],str(t)[1]]:
            octot.append([octo,t])

# %%
len(tocto),len(octot)
# Out:
# (53, 47)

# %% [markdown]
#     portanto temos que para os triangulares :
#     square -(48)-> triangles -(68)-> square
#     pentagonal -(58)-> triangles -(62)-> pentagonal
#     hexagonal -(47)-> triangles -(53)-> hexagonal
#     heptagonal -(38)-> triangles -(45)-> heptagonal
#     octogonal -(53)-> triangles -(47)-> octogonal

# %%
sp = []
ps = []

# %%
for s in sqlist:
    for p in pentlist:
        if [str(s)[-2],str(s)[-1]] == [str(p)[0],str(p)[1]]:
            sp.append([s,p])
        if [str(p)[-2],str(p)[-1]] == [str(s)[0],str(s)[1]]:
            ps.append([p,s])

# %%
len(sp),len(ps)
# Out:
# (25, 35)

# %%
shexa = []
hexas = []

# %%
for s in sqlist:
    for hexa in hexalist:
        if [str(s)[-2],str(s)[-1]] == [str(hexa)[0],str(hexa)[1]]:
            shexa.append([s,hexa])
        if [str(hexa)[-2],str(hexa)[-1]] == [str(s)[0],str(s)[1]]:
            hexas.append([hexa,s])

# %%
len(shexa),len(hexas)
# Out:
# (36, 35)

# %%
shept = []
hepts = []

# %%
for s in sqlist:
    for hept in heptlist:
        if [str(s)[-2],str(s)[-1]] == [str(hept)[0],str(hept)[1]]:
            shept.append([s,hept])
        if [str(hept)[-2],str(hept)[-1]] == [str(s)[0],str(s)[1]]:
            hepts.append([hept,s])

# %%
len(shept),len(hepts)
# Out:
# (28, 32)

# %%
socto = []
octos = []

# %%
for s in sqlist:
    for octo in octolist:
        if [str(s)[-2],str(s)[-1]] == [str(octo)[0],str(octo)[1]]:
            socto.append([s,octo])
        if [str(octo)[-2],str(octo)[-1]] == [str(s)[0],str(s)[1]]:
            octos.append([octo,s])

# %%
len(octos),len(socto)
# Out:
# (23, 22)

# %% [markdown]
#     portanto temos que para os triangulares :
#     square -(48)-> triangles -(68)-> square
#     pentagonal -(58)-> triangles -(62)-> pentagonal
#     hexagonal -(47)-> triangles -(53)-> hexagonal
#     heptagonal -(38)-> triangles -(45)-> heptagonal
#     octogonal -(53)-> triangles -(47)-> octogonal
#
#     portanto temos que para os squares :
#     squares -(25)-> pentagonal -(35)-> squares
#     squares -(36)-> hexagonals -(35)-> squares
#     squares -(28)-> heptagonals -(32)-> squares
#     squares -(23)-> octogonals -(22)-> squares

# %%
phexa = []
hexap = []

# %%
for p in pentlist:
    for hexa in hexalist:
        if [str(p)[-2],str(p)[-1]] == [str(hexa)[0],str(hexa)[1]]:
            phexa.append([p,hexa])
        if [str(hexa)[-2],str(hexa)[-1]] == [str(p)[0],str(p)[1]]:
            hexap.append([hexa,p])

# %%
len(phexa),len(hexap)
# Out:
# (27, 33)

# %%
phept = []
heptp = []

# %%
for p in pentlist:
    for hept in heptlist:
        if [str(p)[-2],str(p)[-1]] == [str(hept)[0],str(hept)[1]]:
            phept.append([p,hept])
        if [str(hept)[-2],str(hept)[-1]] == [str(p)[0],str(p)[1]]:
            heptp.append([hept,p])

# %%
len(phept),len(heptp)
# Out:
# (31, 30)

# %%
pocto = []
octop = []

# %%
for p in pentlist:
    for octo in octolist:
        if [str(p)[-2],str(p)[-1]] == [str(octo)[0],str(octo)[1]]:
            pocto.append([p,octo])
        if [str(octo)[-2],str(octo)[-1]] == [str(p)[0],str(p)[1]]:
            octop.append([octo,p])

# %%
len(pocto),len(octop)
# Out:
# (25, 16)

# %% [markdown]
#     portanto temos que para os triangulares :
#     square -(48)-> triangles -(68)-> square
#     pentagonal -(58)-> triangles -(62)-> pentagonal
#     hexagonal -(47)-> triangles -(53)-> hexagonal
#     heptagonal -(38)-> triangles -(45)-> heptagonal
#     octogonal -(53)-> triangles -(47)-> octogonal
#
#     portanto temos que para os squares :
#     squares -(25)-> pentagonal -(35)-> squares
#     squares -(36)-> hexagonals -(35)-> squares
#     squares -(28)-> heptagonals -(32)-> squares
#     squares -(23)-> octogonals -(22)-> squares
#
#     prontanto temos que para os pentagonals:
#     hexagonal --> pentagonal(33)
#     octogonals --> pentagonals(16)

# %%
for t in trilist:
    for s in sqlist:
        for p in pentlist:
            if [str(t)[-2],str(t)[-1]] == [str(p)[0],str(p)[1]] and [str(p)[-2],str(p)[-1]] == [str(s)[0],str(s)[1]]:
                tps.append([t,p,s])

# %%
tps = []

# %%
len(tps)
tps
# Out:
# [[1035, 3577, 7744],
#  [1081, 8177, 7744],
#  [1128, 2882, 8281],
#  [1275, 7526, 2601],
#  [1326, 2625, 2500],
#  [1431, 3151, 5184],
#  [1540, 4030, 3025],
#  [1653, 5370, 7056],
#  [1711, 1162, 6241],
#  [1830, 3015, 1521],
#  [1953, 5370, 7056],
#  [2016, 1617, 1764],
#  [2211, 1162, 6241],
#  [2415, 1520, 2025],
#  [2628, 2882, 8281],
#  [2775, 7526, 2601],
#  [2850, 5017, 1764],
#  [2926, 2625, 2500],
#  [3081, 8177, 7744],
#  [3240, 4030, 3025],
#  [3321, 2147, 4761],
#  [3486, 8626, 2601],
#  [3655, 5551, 5184],
#  [3828, 2882, 8281],
#  [3916, 1617, 1764],
#  [4095, 9560, 6084],
#  [4186, 8626, 2601],
#  [4753, 5370, 7056],
#  [4851, 5192, 9216],
#  [4950, 5017, 1764],
#  [5050, 5017, 1764],
#  [5151, 5192, 9216],
#  [5253, 5370, 7056],
#  [5886, 8626, 2601],
#  [5995, 9560, 6084],
#  [6216, 1617, 1764],
#  [6328, 2882, 8281],
#  [6555, 5551, 5184],
#  [6786, 8626, 2601],
#  [7021, 2147, 4761],
#  [7140, 4030, 3025],
#  [7381, 8177, 7744],
#  [7626, 2625, 2500],
# ...

# %%
htps = []
tpsh = []

# %%
for tpser in tps:
    for hexa in hexalist:
        if [str(tpser)[-3],str(tpser)[-2]] == [str(hexa)[0],str(hexa)[1]]:
            tpsh.append([tpser,hexa])
        if [str(hexa)[-2],str(hexa)[-1]] == [str(tpser)[1],str(tpser)[2]]:
            htps.append([hexa,tpser])

# %%
len(tpsh),len(htps)
# Out:
# (25, 24)

# %%
[str(tsper)[-3],str(tsper)[-2]]  , [str(hexa)[0],str(hexa)[1]]
# Out:
# (['0', '1'], ['9', '7'])

# %%
for tspher in tsph:
    for hexa in hexalist:
        if [str(tsper)[-3],str(tsper)[-2]] == [str(hexa)[0],str(hexa)[1]]:
            tsph.append([tsper,hexa])
        if [str(hexa)[-2],str(hexa)[-1]] == [str(tsper)[1],str(tsper)[1]]:
            htsp.append([hexa,tsper])

# %%
# ja cortei os TSP;;;
# temos que TPSHex e HexTPS são reais

# %%
#primeiro o TPSHex
tpshh = []
htpsh = []

# %%
for tpsher in tpsh:
    for hept in heptlist:
        if [str(tpsher)[-3],str(tpsher)[-2]] == [str(hept)[0],str(hept)[1]]:
            tpshh.append([tpsher,hept])
        if [str(hept)[-2],str(hept)[-1]] == [str(tpsher)[2],str(tpsher)[3]]:
            htpsh.append([hept,tpsher])

# %%
str(tpsher)[-3],str(tpsher)[-2],str(tpsher)
# Out:
# ('4', '5', '[[9730, 3015, 1521], 2145]')

# %%
str(tpsher)[2],str(tpsher)[3],str(tpsher)
# Out:
# ('9', '7', '[[9730, 3015, 1521], 2145]')

# %%
len(tpshh),len(htpsh)
# Out:
# (23, 9)

# %%
#sobrou o tpshh

# %%
gg = []

# %%
for love in tpshh:
    for octo in octolist:
        if [str(love)[-3],str(love)[-2]] == [str(octo)[0],str(octo)[1]]:
            gg.append([love,octo])
        if [str(octo)[-2],str(octo)[-1]] == [str(love)[3],str(love)[4]]:
            gg.append([octo,love])

# %%
gg
# Out:
# [[[[[1711, 1162, 6241], 4186], 8614], 1408],
#  [4720, [[[2016, 1617, 1764], 6441], 4141]],
#  [5720, [[[2016, 1617, 1764], 6441], 4141]],
#  [[[[2211, 1162, 6241], 4186], 8614], 1408],
#  [1281, [[[8128, 2882, 8281], 8128], 2839]],
#  [4485, [[[8515, 1520, 2025], 2556], 5688]],
#  [5985, [[[8515, 1520, 2025], 2556], 5688]],
#  [[[[8911, 1162, 6241], 4186], 8614], 1408]]

# %%
str(love)[2],str(love)
# Out:
# ('[', '[[[9730, 3015, 1521], 2145], 4558]')

# %%
#sobrou o htpshex

# %%
gg = []

# %%
for love in htpsh:
    for octo in octolist:
        if [str(love)[-4],str(love)[-3]] == [str(octo)[0],str(octo)[1]]:
            gg.append([love,octo])
        if [str(octo)[-2],str(octo)[-1]] == [str(love)[3],str(love)[4]]:
            gg.append([octo,love])

# %%
gg
# Out:
# [[[9211, [[1128, 2882, 8281], 8128]], 2821],
#  [[9517, [[1711, 1162, 6241], 4186]], 8640],
#  [[6426, [[2628, 2882, 8281], 8128]], 2821]]

# %%
str(love)[-4],str(love)[-3],str(love)
# Out:
# ('4', '1', '[1177, [[7750, 5017, 1764], 6441]]')

# %%
str(love)[3],str(love)[4]
# Out:
# ('7', '7')

# %%
#agr o HexTps

# %%
len(htps)
# Out:
# 24

# %%
hhtps = []
htpsh2 = []

# %%
for htpser in htps:
    for hept in heptlist:
        if [str(htpser)[-3],str(htpser)[-2]] == [str(hept)[0],str(hept)[1]]:
            htpsh2.append([htpser,hept])
        if [str(hept)[-2],str(hept)[-1]] == [str(htpser)[1],str(htpser)[2]]:
            hhtps.append([hept,htpser])

# %%
len(hhtps),len(htpsh2)
# Out:
# (7, 0)

# %%
str(htpser)[1],str(htpser)[2],str(htpser)
# Out:
# ('8', '3', '[8385, [8515, 1520, 2025]]')

# %%
gg = []

# %%
for love in hhtps:
    for octo in octolist:
        if [str(love)[-5],str(love)[-4]] == [str(octo)[0],str(octo)[1]]:
            gg.append([love,octo])
        if [str(octo)[-2],str(octo)[-1]] == [str(love)[1],str(love)[2]]:
            gg.append([octo,love])

# %%
str(love)[-5],str(love)[-4] , str(love)
# Out:
# ('8', '1', '[2673, [7381, [8128, 2882, 8281]]]')

# %%
str(love)[1],str(love)[2]
# Out:
# ('2', '6')

# %%
gg
# Out:
# [[[1651, [5151, [5151, 5192, 9216]]], 1680],
#  [3816, [1651, [5151, [5151, 5192, 9216]]]],
#  [6816, [1651, [5151, [5151, 5192, 9216]]]]]

# %%
#TPS IS OUT OF COMBAT

# NOW WE ARE LEFT WITH PST, PTS, STP AND SPT

# %%
pst = []

# %%
for t in trilist:
    for s in sqlist:
        for p in pentlist:
            if [str(p)[-2],str(p)[-1]] == [str(s)[0],str(s)[1]] and [str(s)[-2],str(s)[-1]] == [str(t)[0],str(t)[1]]:
                pst.append([p,s,t])

# %%
len(pst)
# Out:
# 22

# %%
pst
# Out:
# [[5192, 9216, 1653],
#  [3015, 1521, 2145],
#  [7315, 1521, 2145],
#  [6112, 1225, 2556],
#  [1520, 2025, 2556],
#  [1820, 2025, 2556],
#  [4030, 3025, 2556],
#  [3290, 9025, 2556],
#  [1162, 6241, 4186],
#  [2262, 6241, 4186],
#  [3577, 7744, 4465],
#  [8177, 7744, 4465],
#  [3432, 3249, 4950],
#  [5370, 7056, 5671],
#  [1247, 4761, 6105],
#  [2147, 4761, 6105],
#  [4347, 4761, 6105],
#  [1617, 1764, 6441],
#  [1717, 1764, 6441],
#  [5017, 1764, 6441],
#  [7957, 5776, 7626],
#  [2882, 8281, 8128]]

# %%
def euler61_part1():
    
    trilist  = [int(n*(n+1)/2) for n in range(45,141)]
    sqlist   = [int(n**2) for n in range(34,100)]
    pentlist = [int(n*(3*n-1)/2) for n in range(26,82)]
    hexalist = [int(n*(2*n-1)) for n in range(23,71)]
    heptlist = [int(n*(5*n-3)/2) for n in range(21,64)]
    octolist = [int(n*(3*n-2)) for n in range(19,59)]
    
    ohept = []
    hepto = []
    
    hexahepto = []
    heptohexa = []
    ohepthexa = []
    hexaohept = []
    
    for o in octolist:
        for hept in heptlist:
            if hept != o:
                if [str(o)[-2],str(o)[-1]] == [str(hept)[0],str(hept)[1]]:
                    ohept.append([o,hept])
                if [str(hept)[-2],str(hept)[-1]] == [str(o)[0],str(o)[1]]:
                    hepto.append([hept,o])
                    
    for ohepter in ohept:
        for hexa in hexalist:
            if hexa != ohepter:
                if [str(ohepter)[-3],str(ohepter)[-2]] == [str(hexa)[0],str(hexa)[1]]:
                    ohepthexa.append([ohepter,hexa])
                if [str(hexa)[-2],str(hexa)[-1]] == [str(ohepter)[1],str(ohepter)[2]]:
                    hexaohept.append([hexa,ohepter])
                    
                    
    for heptoer in hepto:
        for hexa in hexalist:
            if hexa != heptoer:
                if [str(heptoer)[-3],str(heptoer)[-2]] == [str(hexa)[0],str(hexa)[1]]:
                    heptohexa.append([heptoer,hexa])
                if [str(hexa)[-2],str(hexa)[-1]] == [str(heptoer)[1],str(heptoer)[2]]:
                    hexahepto.append([hexa,heptoer])
    
    
                
    return hepto,ohept

# %%
euler61_part1()
# Out:
# ([[3010, 1045],
#   [8910, 1045],
#   [9211, 1160],
#   [2512, 1281],
#   [8614, 1408],
#   [1918, 1825],
#   [5221, 2133],
#   [6426, 2640],
#   [9828, 2821],
#   [3940, 4033],
#   [3744, 4485],
#   [4347, 4720],
#   [5452, 5208],
#   [2059, 5985],
#   [1071, 7105],
#   [4774, 7400],
#   [1177, 7701],
#   [7480, 8008],
#   [3186, 8640]],
#  [[1045, 4558],
#   [1541, 4141],
#   [1680, 8037],
#   [1825, 2512],
#   [2133, 3367],
#   [3816, 1651],
#   [4033, 3367],
#   [4256, 5688],
#   [4720, 2059],
#   [4961, 6175],
#   [5461, 6175],
#   [5720, 2059],
#   [6256, 5688],
#   [6533, 3367],
#   [6816, 1651],
#   [9633, 3367]])

# %%
def euler61_part0():
    
    trilist  = [int(n*(n+1)/2) for n in range(45,141)]
    sqlist   = [int(n**2) for n in range(34,100)]
    pentlist = [int(n*(3*n-1)/2) for n in range(26,82)]
    hexalist = [int(n*(2*n-1)) for n in range(23,71)]
    heptlist = [int(n*(5*n-3)/2) for n in range(21,64)]
    octolist = [int(n*(3*n-2)) for n in range(19,59)]
    
    mother_list = [trilist] + [sqlist] + [pentlist] + [hexalist] + [heptlist] + [octolist]
    for mom in mother_list:
        for son in mom:
            if son %100 < 10:
                mom.remove(son)
    daughter = []
    
    for lista in mother_list:
        mother_list.remove(lista)
        for listb in mother_list:
            if listb != lista:
                curr_ans = []
                sym_ans = []
                for a in lista:
                    for b in listb:
                        if [str(a)[-2],str(a)[-1]] == [str(b)[0],str(b)[1]]:
                            curr_ans.append([a,b])
                        if [str(b)[-2],str(b)[-1]] == [str(a)[0],str(a)[1]]:
                            sym_ans.append([b,a])
                daughter += [[curr_ans],[sym_ans]]
            
    for dah in daughter:
        for d in dah:
            for pair in d:
                if pair[1] % 100 < 10:
                    d.remove(pair)
    for dah in daughter:
        for d in dah:
            for pair in d:
                if pair[1] % 100 < 10:
                    d.remove(pair)   
    for dah in daughter:
        for d in dah:
            for pair in d:
                if pair[1] % 100 < 10:
                    d.remove(pair)
    return daughter

# %%
k = euler61_part0()
t1 = k[0]
t2 = k[1]
t3 = k[2]
t4 = k[3]
t5 = k[4]
s1 = k[5]
s2 = k[6]
s3 = k[7]
s4 = k[8]
p1 = k[9]
p2 = k[10]
p3 = k[11]
hx1 = k[12]
hx2 = k[13]
hp1 = k[14]

# %%
1128 in trilist
1128 in hexalist
# Out:
# True

# %%
2821 in octolist
# Out:
# True

# %%
2116 in sqlist
# Out:
# True

# %%
1651 in heptlist , 1617 in pentlist, 1653 in trilist
# Out:
# (True, True, True)

# %% [markdown]
# toshept
# or
# hexaoshept

# %%
7107 % 100
# Out:
# 7

# %%
def euler61_part3():
    
    trilist  = [int(n*(n+1)/2) for n in range(45,141)]
    sqlist   = [int(n**2) for n in range(34,100)]
    pentlist = [int(n*(3*n-1)/2) for n in range(26,82)]
    hexalist = [int(n*(2*n-1)) for n in range(23,71)]
    heptlist = [int(n*(5*n-3)/2) for n in range(21,64)]
    octolist = [int(n*(3*n-2)) for n in range(19,59)]
    
    for t in trilist:
        if t % 100 < 10:
            trilist.remove(t)
    for s in sqlist:
        if s % 100 < 10:
            while s in sqlist:
                sqlist.remove(s)
    for p in pentlist:
        if p % 100 < 10:
            pentlist.remove(p)
    for h6 in hexalist:
        if h6 % 100 < 10:
            hexalist.remove(h6)
    for h7 in heptlist:
        if h7 % 100 < 10:
            heptlist.remove(h7)
    for o in octolist:
        if o % 100 < 10:
            octolist.remove(o)
             
    print(sqlist)
    mother_list = [trilist] + [sqlist] + [pentlist] + [hexalist] + [heptlist] + [octolist]           
    daughter = []
    
    for lista in mother_list:
        mother_list.remove(lista)
        for listb in mother_list:
            curr_ans = []
            sym_ans = []
            for a in lista:
                for b in listb:
                    if [str(a)[-2],str(a)[-1]] == [str(b)[0],str(b)[1]]:
                        curr_ans.append([a,b])
                    if [str(b)[-2],str(b)[-1]] == [str(a)[0],str(a)[1]]:
                        sym_ans.append([b,a])
            daughter += [[curr_ans,sym_ans]]
    for dau in daughter[:6]:
        for uad in daughter[6:]:
            return

# %%
euler61_part3()
# Out:
# [1156, 1225, 1296, 1369, 1444, 1521, 1681, 1764, 1849, 1936, 2025, 2116, 2304, 2500, 2704, 2916, 3025, 3136, 3249, 3364, 3481, 3721, 3844, 3969, 4096, 4225, 4356, 4489, 4624, 4761, 5041, 5184, 5329, 5476, 5625, 5776, 5929, 6084, 6241, 6561, 6724, 6889, 7056, 7225, 7396, 7569, 7744, 7921, 8281, 8464, 8649, 8836, 9025, 9216, 9604]

# %%
2500 % 100
# Out:
# 0

# %%
tttt = []
pppp = []
ssss = []
uuuu = []

# %%
for t in trilist:
    if t % 100 < 10:
        trilist.remove(t)
for s in sqlist:
    if s % 100 < 10:
        while s in sqlist:
            sqlist.remove(s)
            print(s)
for p in pentlist:
    if p % 100 < 10:
        pentlist.remove(p)
for h6 in hexalist:
    if h6 % 100 < 10:
        hexalist.remove(h6)
for h7 in heptlist:
    if h7 % 100 < 10:
        heptlist.remove(h7)
for o in octolist:
    if o % 100 < 10:
        octolist.remove(o)

# %%
for t in trilist:
    for s in sqlist:
        for p in pentlist:
            for h6 in hexalist:
                for h7 in heptlist:
                    if [str(t)[-2],str(t)[-1]] == [str(p)[0],str(p)[1]] and [str(p)[-2],str(p)[-1]] == [str(s)[0],str(s)[1]] and [str(s)[-2],str(s)[-1]] == [str(h7)[0],str(h7)[1]] and [str(h7)[-2],str(h7)[-1]] == [str(h6)[0],str(h6)[1]] :
                        tttt.append([t,p,s,h7,h6])
                    if [str(t)[-2],str(t)[-1]] == [str(h7)[0],str(h7)[1]] and [str(h7)[-2],str(h7)[-1]] == [str(s)[0],str(s)[1]] and [str(s)[-2],str(s)[-1]] == [str(h6)[0],str(h6)[1]] and [str(h6)[-2],str(h6)[-1]] == [str(p)[0],str(p)[1]] :
                        pppp.append([t,p,s,h7,h6])
                    if [str(t)[-2],str(t)[-1]] == [str(p)[0],str(p)[1]] and [str(p)[-2],str(p)[-1]] == [str(h6)[0],str(h6)[1]] and [str(h6)[-2],str(h6)[-1]] == [str(h7)[0],str(h7)[1]] and [str(h7)[-2],str(h7)[-1]] == [str(s)[0],str(s)[1]] :
                        ssss.append([t,p,s,h7,h6])
                    if [str(t)[-2],str(t)[-1]] == [str(s)[0],str(s)[1]] and [str(s)[-2],str(s)[-1]] == [str(h6)[0],str(h6)[1]] and [str(h6)[-2],str(h6)[-1]] == [str(p)[0],str(p)[1]] and [str(p)[-2],str(p)[-1]] == [str(h7)[0],str(h7)[1]] :
                        uuuu.append([t,p,s,h7,h6])

# %%
tttt,ssss,pppp,uuuu
# Out:
# ([[1540, 4030, 3025, 2512, 1225],
#   [1711, 1162, 6241, 4141, 4186],
#   [2211, 1162, 6241, 4141, 4186],
#   [2415, 1520, 2025, 2512, 1225],
#   [3240, 4030, 3025, 2512, 1225],
#   [4851, 5192, 9216, 1651, 5151],
#   [5151, 5192, 9216, 1651, 5151],
#   [7140, 4030, 3025, 2512, 1225],
#   [8515, 1520, 2025, 2512, 1225],
#   [8911, 1162, 6241, 4141, 4186]],
#  [[1326, 2625, 8836, 5688, 2556],
#   [1711, 1162, 5184, 1651, 6216],
#   [2145, 4510, 5329, 3553, 1035],
#   [2211, 1162, 5184, 1651, 6216],
#   [2346, 4676, 7396, 2673, 7626],
#   [2415, 1520, 5184, 1651, 2016],
#   [2926, 2625, 8836, 5688, 2556],
#   [7626, 2625, 8836, 5688, 2556],
#   [8515, 1520, 5184, 1651, 2016],
#   [8646, 4676, 7396, 2673, 7626],
#   [8911, 1162, 5184, 1651, 6216],
#   [9045, 4510, 5329, 3553, 1035]],
#  [[1431, 5017, 8649, 3186, 4950],
#   [2080, 4510, 3721, 8037, 2145],
#   [2556, 5551, 8836, 5688, 3655],
#   [4095, 4187, 1764, 9517, 6441],
#   [4656, 5551, 8836, 5688, 3655],
# ...

# %%
ttt,sss,ppp = Out[348]

# %%
ttt
# Out:
# [[1540, 4030, 3025, 2512, 1225],
#  [1711, 1162, 6241, 4141, 4186],
#  [2211, 1162, 6241, 4141, 4186]]

# %%
sss
# Out:
# [[1431, 5017, 8649, 3186, 4950], [2080, 4510, 3721, 8037, 2145]]

# %%
ppp
# Out:
# [[1326, 2625, 8836, 5688, 2556],
#  [1711, 1162, 5184, 1651, 6216],
#  [2145, 4510, 5329, 3553, 1035],
#  [2211, 1162, 5184, 1651, 6216]]

# %%
octolist
# Out:
# [1045,
#  1160,
#  1281,
#  1541,
#  1680,
#  1825,
#  1976,
#  2133,
#  2296,
#  2465,
#  2640,
#  2821,
#  3816,
#  4033,
#  4256,
#  4485,
#  4720,
#  4961,
#  5461,
#  5720,
#  5985,
#  6256,
#  6533,
#  6816,
#  8321,
#  8640,
#  8965,
#  9296,
#  9633,
#  9976]

# %%
uuuu[-1]
# Out:
# [8646, 1520, 4624, 2059, 2415]

# %%
pppp
# Out:
# [[1431, 5017, 8649, 3186, 4950],
#  [2080, 4510, 3721, 8037, 2145],
#  [2556, 5551, 8836, 5688, 3655],
#  [4095, 4187, 1764, 9517, 6441],
#  [4656, 5551, 8836, 5688, 3655],
#  [5356, 5551, 8836, 5688, 3655],
#  [5995, 4187, 1764, 9517, 6441],
#  [8256, 5551, 8836, 5688, 3655],
#  [9180, 4510, 3721, 8037, 2145]]

# %%
aaaa = []
bbbb = []
cccc = [] 
dddd = []

# %%
for t in trilist:
    for s in sqlist:
        for p in pentlist:
            for h6 in hexalist:
                for h7 in heptlist:
                    if [str(t)[-2],str(t)[-1]] == [str(p)[0],str(p)[1]] and [str(p)[-2],str(p)[-1]] == [str(h7)[0],str(h7)[1]] and [str(h7)[-2],str(h7)[-1]] == [str(s)[0],str(s)[1]] and [str(s)[-2],str(s)[-1]] == [str(h6)[0],str(h6)[1]] :
                        aaaa.append([t,p,s,h7,h6])
                    if [str(t)[-2],str(t)[-1]] == [str(h7)[0],str(h7)[1]] and [str(h7)[-2],str(h7)[-1]] == [str(p)[0],str(p)[1]] and [str(p)[-2],str(p)[-1]] == [str(h6)[0],str(h6)[1]] and [str(h6)[-2],str(h6)[-1]] == [str(s)[0],str(s)[1]] :
                        bbbb.append([t,p,s,h7,h6])
                    if [str(t)[-2],str(t)[-1]] == [str(p)[0],str(p)[1]] and [str(p)[-2],str(p)[-1]] == [str(h6)[0],str(h6)[1]] and [str(h6)[-2],str(h6)[-1]] == [str(s)[0],str(s)[1]] and [str(s)[-2],str(s)[-1]] == [str(h7)[0],str(h7)[1]] :
                        cccc.append([t,p,s,h7,h6])
                    if [str(t)[-2],str(t)[-1]] == [str(s)[0],str(s)[1]] and [str(s)[-2],str(s)[-1]] == [str(p)[0],str(p)[1]] and [str(p)[-2],str(p)[-1]] == [str(h7)[0],str(h7)[1]] and [str(h7)[-2],str(h7)[-1]] == [str(h6)[0],str(h6)[1]] :
                        dddd.append([t,p,s,h7,h6])

# %% [markdown]
# T-S-H6-P-H7
# t-s-p-h7-h6
# T-P-S-H7-H6
# t-p-h6-s-h7
# T-P-H6-H7-S
# t-p-h7-s-h6
# T-H7-S-H6-P
# t-h7-p-h6-s

# %%
dddd
# Out:
# []

# %%
octolist
# Out:
# [1045,
#  1160,
#  1281,
#  1541,
#  1680,
#  1825,
#  1976,
#  2133,
#  2296,
#  2465,
#  2640,
#  2821,
#  3816,
#  4033,
#  4256,
#  4485,
#  4720,
#  4961,
#  5461,
#  5720,
#  5985,
#  6256,
#  6533,
#  6816,
#  8321,
#  8640,
#  8965,
#  9296,
#  9633,
#  9976]
